# %%
###
# Variable: Todas 
# Periodo: Datos en la DB
# Proyecto Zorro Abarrotero
# Graph: Varios
# Roberto Andrade Fonseca (c)
# Inicio: 7 de agosto de 2019
# Para: Avignon
###
import chart_studio.plotly
#import plotly.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as ff
import plotly.offline as offline
import pandas as pd

import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output

# Read in data from csv file
# Usamos el CSV modificado para contar con registros únicos
data_file = "/home/randrade/proyectos/zorro_abarrotero/dev/db/datasets/data_promedios_calificaciones.csv"
#df = pd.read_csv(data_file,index_col=2)
df = pd.read_csv(data_file)
#df = df.sort_values(by=['Tienda'])
#dimension='Atención en cajas'
dimension='Orden y limpieza'
df = df.loc[df['cadena_id'] == 1, ['nombre_tienda', 'dimension','mediciones', 'promedio']]


df = df.loc[df['dimension'] == dimension]

print(df)

#df = df.loc[df['Cadena'] == 'Zorro Abarrotero']
# Out:
#                     nombre_tienda         dimension  mediciones  promedio
# 237                  Zorro Aragón  Orden y limpieza           3    100.00
# 238                   Zorro Peñón  Orden y limpieza           3    100.00
# 239        Zorro Nicolás Romero 2  Orden y limpieza           3    100.00
# 240             Zorro San Juanico  Orden y limpieza           3    100.00
# 241               Zorro Campestre  Orden y limpieza           3     97.67
# 242               Zorro Tultitlán  Orden y limpieza           3     97.67
# 243                  Zorro Chalco  Orden y limpieza           3     97.62
# 244                 Zorro Izcalli  Orden y limpieza           3     97.62
# 245                   Zorro Minas  Orden y limpieza           2     96.50
# 246            Zorro Chimalhuacán  Orden y limpieza           3     95.33
# 247               Zorro Texcoco 2  Orden y limpieza           3     95.33
# 248              Zorro Aeropuerto  Orden y limpieza           3     95.24
# 249                Zorro Tenayuca  Orden y limpieza           3     95.24
# 250              Zorro Ixtapaluca  Orden y limpieza           3     93.00
# 251         Zorro Vicente Villada  Orden y limpieza           3     92.95
# 252          Zorro Alta Tensión 2  Orden y limpieza           3     90.67
# 253               Zorro Tecámac 2  Orden y limpieza           3     90.67
# 254                 Zorro Texcoco  Orden y limpieza           3     90.62
# 255               Zorro Amecameca  Orden y limpieza           3     90.57
# 256              Zorro Ecatepec 3  Orden y limpieza           3     90.57
# 257                  Zorro Iguala  Orden y limpieza           3     90.57
# 258            Zorro Paseo Chalco  Orden y limpieza           3     90.57
# 259             Zorro Contreras 2  Orden y limpieza           3     88.29
# 260              Zorro Cuautitlán  Orden y limpieza           3     88.29
# 261                  Zorro Ozumba  Orden y limpieza           3     88.29
# 262               Zorro Pantitlán  Orden y limpieza           3     88.29
# 263             Zorro Cien Metros  Orden y limpieza           3     88.19
# 264              Zorro Centenario  Orden y limpieza           3     88.19
# 265                Zorro Coacalco  Orden y limpieza           3     88.00
# 266             Zorro Vía Morelos  Orden y limpieza           3     88.00
# ..                            ...               ...         ...       ...
# 286  Flecha Abarrotera Xochimilco  Orden y limpieza           3     78.57
# 287              Zorro Central H2  Orden y limpieza           3     78.52
# 288                   Zorro Reyes  Orden y limpieza           3     78.52
# 289         Zorro Calzada La Viga  Orden y limpieza           3     78.33
# 290            Zorro Tlalnepantla  Orden y limpieza           4     76.75
# 291            Zorro Alta Tensión  Orden y limpieza           3     76.43
# 292         Zorro Carrillo Puerto  Orden y limpieza           3     76.29
# 293          Zorro Nezahualcóyotl  Orden y limpieza           3     76.24
# 294              Zorro Central Q6  Orden y limpieza           3     76.14
# 295    Zorro Carretera Cuernavaca  Orden y limpieza           3     76.05
# 296               Zorro Río Hondo  Orden y limpieza           3     76.00
# 297       Zorro Valle de Chalco 2  Orden y limpieza           3     73.57
# 298             Zorro Chicoloapan  Orden y limpieza           3     71.52
# 299                  Zorro Roldán  Orden y limpieza           3     71.52
# 300                 Zorro Tecámac  Orden y limpieza           3     71.52
# 301         Zorro Valle de Chalco  Orden y limpieza           3     66.62
# 302                Zorro Toluca 2  Orden y limpieza           3     66.43
# 303                 Zorro Estacas  Orden y limpieza           3     64.43
# 304                    Zorro León  Orden y limpieza           3     64.43
# 305             Cazador Comercial  Orden y limpieza           3     64.14
# 306          Zorro Alta Tensión 3  Orden y limpieza           3     64.05
# 307     Zorro Ermita Iztapalapa 2  Orden y limpieza           3     64.00
# 308              Zorro Tulancingo  Orden y limpieza           3     62.10
# 309                Zorro Irapuato  Orden y limpieza           3     57.29
# 310   Cazador Comercial Naucalpan  Orden y limpieza           3     54.86
# 311                Zorro Toluca 1  Orden y limpieza           3     54.71
# 312              Zorro Cuajimalpa  Orden y limpieza           3     49.90
# 313                Zorro Jiutepec  Orden y limpieza           3     49.71
# 314               Zorro Querétaro  Orden y limpieza           3     47.52
# 315                 Zorro Picacho  Orden y limpieza           3     42.86
#
# [79 rows x 4 columns]
